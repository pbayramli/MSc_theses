# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import color
import pandas as pd

# %% [markdown]
# ### Load excel data

# %%
df =pd.read_csv('data\orientationdata\point_data_section_0.csv')
#df = df.iloc[:, 0].str.split(',', expand=True)
df.columns = ['X', 'Y','Z','formation','section']
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e9b517a6d13f> in <module>
# ----> 1 df =pd.read_csv('data\orientationdata\point_data_section_0.csv')
#       2 #df = df.iloc[:, 0].str.split(',', expand=True)
#       3 df.columns = ['X', 'Y','Z','formation','section']
#       4 df
#
# ~\python\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~\python\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~\python\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~\python\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~\python\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~\python\lib\site-packages\pandas\io\parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~\python\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data\\orientationdata\\point_data_section_0.csv'

# %% [markdown]
# ### Additional Dimentions

# %%
#add dip
df.loc[:, 'dip'] = '0'

#add azimuth
df.loc[:, 'azimuth'] = '90'

#add polarity
df.loc[:, 'polarity'] = '1'

df = df[['X', 'Y', 'Z','dip','azimuth','polarity','formation','section']]


df
# Out:
#        X  Y    Z dip azimuth polarity   formation section
# 0      0  0  -45   0      90        1        topo  grades
# 1     36  0  -45   0      90        1        topo  grades
# 2     59  0  -40   0      90        1        topo  grades
# 3    110  0  -39   0      90        1        topo  grades
# 4    204  0  -42   0      90        1        topo  grades
# ..   ... ..  ...  ..     ...      ...         ...     ...
# 188  108  0   -6   0      90        1  quartzite2  grades
# 189  129  0  -36   0      90        1  quartzite2  grades
# 190  130  0  -66   0      90        1  quartzite2  grades
# 191  118  0 -103   0      90        1  quartzite2  grades
# 192  105  0 -149   0      90        1  quartzite2  grades
#
# [193 rows x 8 columns]

# %%
#save the data at the end
df.to_csv(r'data\orientationdata\orientation_data_all.csv', index = False)
