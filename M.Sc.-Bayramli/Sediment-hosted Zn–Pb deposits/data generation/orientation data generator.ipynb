# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd

# %% [markdown]
# ### Load excel data

# %%
df =pd.read_csv('data\orientationdata\point_data_CD.csv')
#df = df.iloc[:, 0].str.split(',', expand=True)
df.columns = ['X', 'Y','Z','formation','section']
df
# Out:
#        X     Y     Z       formation section
# 0   1025  -308  -512            topo      CD
# 1   1025  -388  -469            topo      CD
# 2   1025  -464  -434            topo      CD
# 3   1025  -524  -396            topo      CD
# 4   1025  -625  -355            topo      CD
# ..   ...   ...   ...             ...     ...
# 79  1025 -1686  -856  LowerYunlongFm      CD
# 80  1025 -1882  -932  LowerYunlongFm      CD
# 81  1025 -1991  -986  LowerYunlongFm      CD
# 82  1025 -2133 -1060  LowerYunlongFm      CD
# 83  1025 -2230 -1104  LowerYunlongFm      CD
#
# [84 rows x 5 columns]

# %% [markdown]
# ### Additional Dimentions

# %%
#add dip
df.loc[:, 'dip'] = '0'

#add azimuth
df.loc[:, 'azimuth'] = '90'

#add polarity
df.loc[:, 'polarity'] = '1'

df = df[['X', 'Y', 'Z','dip','azimuth','polarity','formation','section']]


df
# Out:
#        X     Y     Z dip azimuth polarity       formation section
# 0   1025  -308  -512   0      90        1            topo      CD
# 1   1025  -388  -469   0      90        1            topo      CD
# 2   1025  -464  -434   0      90        1            topo      CD
# 3   1025  -524  -396   0      90        1            topo      CD
# 4   1025  -625  -355   0      90        1            topo      CD
# ..   ...   ...   ...  ..     ...      ...             ...     ...
# 79  1025 -1686  -856   0      90        1  LowerYunlongFm      CD
# 80  1025 -1882  -932   0      90        1  LowerYunlongFm      CD
# 81  1025 -1991  -986   0      90        1  LowerYunlongFm      CD
# 82  1025 -2133 -1060   0      90        1  LowerYunlongFm      CD
# 83  1025 -2230 -1104   0      90        1  LowerYunlongFm      CD
#
# [84 rows x 8 columns]

# %%
#save the data at the end
df.to_csv(r'data\orientationdata\orientation_data_CD.csv', index = False)
